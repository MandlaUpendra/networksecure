# %%
import os

os.getcwd()
# Out:
# Running cells with 'venv (Python 3.10.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p d:\projects\NetworkSecurity\venv ipykernel --update-deps --force-reinstall'
